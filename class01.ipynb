# %% [markdown]
# <a href="https://colab.research.google.com/github/hajrayounus/python-classes-/blob/main/class01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world ")
# Out:
# hello world

# %% [markdown]
# # variable

# %%
fav_celebrity ="hajra "
fav_game = "ludo "
fav_food = "briyani"
print ( fav_celebrity +fav_game +fav_food )
# Out:
# hajra ludo briyani

# %% [markdown]
# # **concatiation :**

# %%
first_name  = "HAJRA "
last_name = "younus"
print (first_name + last_name)
# Out:
# HAJRA younus
