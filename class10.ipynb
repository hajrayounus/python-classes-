# %% [markdown]
# <a href="https://colab.research.google.com/github/hajrayounus/python-classes-/blob/main/class10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **4 pillers of OOP**
#
# Encapsulation – (hide data)Data aur methods ko ek class ke andar rakhna.
# Example: class Student:
# Inheritance – (reusing code) Ek class doosri class ke features use karti hai.
# Example: class Dog(Animal):
# Polymorphism –(same action , different behaviors) Same method different classes mein different kaam karta hai.
# Example: speak() dog mein "Bark", cat mein "Meow".
# Abstraction – (hiding complexcity)Sirf zaroori cheez dikhana aur internal details hide karna.
# Example: car.start() — humein engine ka internal process nahi dekhna padta.

# %%
import random
for i in range (10):
  value = random.randint(1,100)
  print (value, end = " ")
# Out:
# 82 21 10 9 33 86 35 9 85 24

# %% [markdown]
# problem 01:
#
# A few years ago, NASA made history with the first controlled flight on another planet. Its latest Mars Rover, Perseverance, has onboard a 50cm high helicopter called Ingenuity. Ingenuity made its third flight, during which it flew faster and further than it had on any of its test flights on Earth. Interestingly, Ingenuity uses Python for some of its flight modeling software!
#
# Ingenuity on the surface of Mars (source: NASA)
#
# When programming Ingenuity, one of the things that NASA engineers need to account for is the fact that due to the weaker gravity on Mars, an Earthling's weight on Mars is 37.8% of their weight on Earth. Write a Python program that prompts an Earthling to enter their weight on Earth and prints their calculated weight on Mars.
#
# The output should be rounded to two decimal places when necessary. Python has a round function which can help you with this. You pass in the value to be rounded and the number of decimal places to use. In the example below, the number 3.1415926 is rounded to 2 decimal places which is 3.14.

# %%
def mars_weight():
  user_input = float(input("enter your earth weight : "))
  mars_weight : float =  user_input * 0.378
  rounded_weight : float = round(mars_weight, 2)
  print(f"your mars_weight is {mars_weight}kg")

mars_weight()
# Out:
# enter your earth weight : 3.1415926
# your mars_weight is 1.1875220028kg

# %%
# your all planet weight

planetary_weight_constant ={
    "Mercury" : 37.6,
    "Venus" : 88.9,
    "Mars" : 37.8,
    "Jupiter" : 236.0,
    "Saturn" : 108.1,
    "Uranus" : 81.5,
    "Neptune" : 114.0
}

def planet_weight ():
  earth_weight = float(input("enter your earth weight : "))
  planet_of_choice = str(input("enter the name of the planet your are going to vist: "))

  if planet_of_choice in planetary_weight_constant:
    planetary_weight = earth_weight * planetary_weight_constant[planet_of_choice] / 100
    rounded_weight = round(planetary_weight, 2)
    print(f"your weight on {planet_of_choice} is {rounded_weight}kg")

  else:
    print("we can only calculate solar system values: ")

planet_weight()
# Out:
# enter your earth weight : 72
# enter the name of the planet your are going to vist: Mars
# your weight on Mars is 27.22kg
