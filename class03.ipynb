# %% [markdown]
# <a href="https://colab.research.google.com/github/hajrayounus/python-classes-/blob/main/class03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **boolean **

# %%
is_logged_in = True
are_road_closed = True
are_internet_closed = False
print(is_logged_in)
print (type(are_internet_closed))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# **comparision operators**

# %%
# == equal to
# != not equal to
# >greater than
# < less than
# >= greater then equal to
# <= less than equal to

a = 90
b = 30
print (a == b)
print (a != b)
print (a > b)
print (a < b)
print (a <= b)
print ( a >= b)
# Out:
# False
# True
# True
# False
# False
# True

# %% [markdown]
# **condition if else **

# %%
my_age = 17
if (my_age >= 18):
  print ("you are allowed")
else:
  print ("you are not allowed")
# Out:
# you are not allowed

# %%
#input example
name = input("what is your name? ")
print (f"hello:"+ name + "!")
# Out:
# what is your name? hajra
# hello:hajra!

# %%
#conditioanl statement:
age = int (input("enter your age :"))
if ( age < 18 ):
  print ("you are minor ")
elif (age >= 50 ):
  print ("you are old person ")
elif (age == 18):
  print ("you are young person ")
else:
  print ("you are adult ")
# Out:
# enter your age :60
# you are old person

# %%
#logical operators:
#and , or
age = int(input("enter your age: "))
weight = int(input("enter your weight: "))

if (age < 18):
  print("you are a minor: ")
if (age < 18 or weight >= 50):
  print ("you can sit ")
elif (age >=18 and weight <=79 ):
  print ("you are a young person ")
elif (age >= 80 and weight >=80 ):
  print ("you can sit ")
else :
  print ("you can't sit to the rollercoaster ")
# Out:
# enter your age: 10
# enter your weight: 40
# you are a minor:
# you can sit
